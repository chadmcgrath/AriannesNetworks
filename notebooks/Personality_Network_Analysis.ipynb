# %% [markdown]
# # AriannesNetworks - Personality Network Analysis
#
# This notebook provides an interactive interface for running personality network analysis based on the Herrera-Bennett & Rhemtulla (2021) study.
#
# ## Overview
# - **Data**: NEO and IPIP personality inventories
# - **Analysis**: Network construction, centrality measures, and bootstrap validation
# - **Visualization**: Interactive network plots and statistical summaries
#
# ## Quick Start
# 1. Run the setup cell below
# 2. Load your data
# 3. Choose analysis type (demo, quick, full)
# 4. View results and visualizations

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Add src directory to path
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / 'src'))

# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')

# Import AriannesNetworks modules
from ide_interface import AriannesNetworksIDE, create_ide_interface, quick_analysis
from config_manager import ConfigManager

# Set up visualization
plt.style.use('default')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

print("✅ Setup complete! AriannesNetworks is ready to use.")

# %% [markdown]
# ## 2. Initialize Analysis Interface

# %%
# Create the IDE interface
ide = create_ide_interface()

print("🔧 AriannesNetworks IDE Interface initialized")
print("📊 Ready to load data and run analysis")

# %% [markdown]
# ## 3. Load Data

# %%
# Load the personality data
data = ide.load_data()

# Get data summary
summary = ide.get_data_summary()

print("📈 Data Summary:")
print(f"   Shape: {summary['shape']}")
print(f"   Missing values: {summary['missing_values']:,}")
print(f"   Memory usage: {summary['memory_usage']:.2f} MB")

print("\n📋 Column Categories:")
for category, columns in summary['column_categories'].items():
    print(f"   {category}: {len(columns)} variables")
    if len(columns) <= 10:
        print(f"      {columns[:10]}")
    else:
        print(f"      {columns[:5]} ... {columns[-5:]}")

# %% [markdown]
# ## 4. Run Analysis
#
# Choose your analysis type:
# - **demo**: Quick demonstration (10 variables each)
# - **quick**: Standard analysis (15 variables each)
# - **full**: Complete analysis (all variables + bootstrap)

# %%
# Choose analysis type
analysis_type = 'demo'  # Change to 'quick' or 'full' as needed

# Run the analysis
results = ide.run_analysis(analysis_type)

print(f"✅ {analysis_type.title()} analysis completed!")
